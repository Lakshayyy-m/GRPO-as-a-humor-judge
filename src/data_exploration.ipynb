# %%
import pandas as pd

# Load the two CSV files
df1 = pd.read_csv('2638_humor_annotated_no_squibs.csv')
df2 = pd.read_csv('32952_with_humor_label_no_squibs.csv')

# Check column names to make sure we're accessing the right ones
print("File 1 columns:", df1.columns.tolist())
print("File 2 columns:", df2.columns.tolist())

# Assuming columns are named 'title' and 'label' in the first file
# and 'abstract', 'title', 'humor_label' in the second file
# Rename columns if needed to match for merging
if 'humor_label' in df2.columns and 'label' not in df2.columns:
    df2 = df2.rename(columns={'humor_label': 'label'})

# Merge dataframes on title
merged_df = pd.merge(df1[['title', 'label']], 
                     df2[['abstract', 'title']],
                     on='title',
                     how='inner')

# Filter to keep only rows where label is 1
result_df = merged_df[merged_df['label'] == 1]

# Keep only the requested columns: abstract, title, and label
result_df = result_df[['abstract', 'title', 'label']]

# Save the result to a new CSV file
result_df.to_csv('merged_humor_data_label_1.csv', index=False)

# Print summary statistics
print(f"Original file 1 rows: {len(df1)}")
print(f"Original file 2 rows: {len(df2)}")
print(f"Matched rows: {len(merged_df)}")
print(f"Rows with label=1: {len(result_df)}")
# Out:
# File 1 columns: ['title', 'label']
# File 2 columns: ['abstract', 'title', 'source', 'year', 'humor_label']
# Original file 1 rows: 2638
# Original file 2 rows: 32952
# Matched rows: 2345
# Rows with label=1: 488

# %% [markdown]
# I need you to perform a few task first based on this abstract and title categorize the title in one of the 20 categories mentioned below
#
# abstract :-
#
# "When scaled to hundreds of billions of parameters, pretrained language models such as GPT-3 (Brown et al., 2020) achieve remarkable few-shot performance. However, enormous amounts of compute are required for training and applying such big models, resulting in a large carbon footprint and making it difficult for researchers and practitioners to use them. We show that performance similar to GPT-3 can be obtained with language models that are much ""greener"" in that their parameter count is several orders of magnitude smaller. This is achieved by converting textual inputs into cloze questions that contain a task description, combined with gradient-based optimization; exploiting unlabeled data gives further improvements. We identify key factors required for successful natural language understanding with small language models.",It's Not Just Size That Matters: Small Language Models Are Also Few-Shot Learners,1
#
# 1. Anecdotal: Named after the word anecdote (which stems from the Greek term meaning “unpublished”); refers to comic personal stories that may be true or partly true but embellished.
# 2. Blue: Also called off-color, or risque (from the French word for “to risk”); relies on impropriety or indecency for comic effect. (The name probably derives from the eighteenth-century use of the word blue to refer to morally strict standards — hence the phrase “blue laws” to refer to ordinances restricting certain behavior on the Sabbath). A related type is broad humor, which refers to unrestrained, unsubtle humor often marked by coarse jokes and sexual situations.
# 3. Burlesque: Ridicules by imitating with caricature, or exaggerated characterization. The association with striptease is that in a bygone era, mocking skits and ecdysiastic displays were often on the same playbills in certain venues.
# 4. Dark/Gallows/Morbid: Grim or depressing humor dealing with misfortune and/or death and with a pessimistic outlook.
# 5. Deadpan/Dry: Delivered with an impassive, expressionless, matter-of-fact presentation.
# 6. Droll: From the Dutch word meaning “imp”; utilizes capricious or eccentric humor.
# 7. Epigrammatic: Humor consisting of a witty saying such as “Too many people run out of ideas long before they run out of words.” (Not all epigrams are humorous, however.) Two masters of epigrammatic humor are Benjamin Franklin (as the author of Poor Richard’s Almanackand Oscar Wilde.
# 8. Farcical: Comedy based on improbable coincidences and with satirical elements, punctuated at times with overwrought, frantic action. (It, like screwball comedy — see below — shares many elements with a comedy of errors.) Movies and plays featuring the Marx Brothers are epitomes of farce. The adjective also refers to incidents or proceedings that seem too ridiculous to be true.
# 9. High/highbrow: Humor pertaining to cultured, sophisticated themes.
# 10. Hyperbolic: Comic presentation marked by extravagant exaggeration and outsized characterization.
# 11. Ironic: Humor involving incongruity and discordance with norms, in which the intended meaning is opposite, or nearly opposite, to the literal meaning. (Not all irony is humorous, however.)
# 12. Juvenile/sophomoric: Humor involving childish themes such as pranks, name-calling, and other immature behavior.
# 13. Mordant: Caustic or biting humor (the word stems from a Latin word meaning “to bite”). Not to be confused with morbid humor (see above).
# 14. Parodic: Comic imitation often intended to ridicule an author, an artistic endeavor, or a genre.
# 15. Satirical: Humor that mocks human weaknesses or aspects of society.
# 16. Screwball: Akin to farce in that it deals with unlikely situations and responses to those situations; distinguished, like farcical humor, by exaggerated characterizations and episodes of fast-paced action.
# 17. Self-deprecating: Humor in which performers target themselves and their foibles or misfortunes for comic effect. Stand-up comedian Rodney Dangerfield was a practitioner of self-deprecating humor.
# 18. Situational: Humor arising out of quotidian situations; it is the basis of sitcoms, or situation comedies. Situational comedies employ elements of farce, screwball, slapstick, and other types of humor.
# 19. Slapstick: Comedy in which mock violence and simulated bodily harm are staged for comic effect; also called physical comedy. The name derives from a prop consisting of a stick with an attached piece of wood that slapped loudly against it when one comedian struck another with it, enhancing the effect. The Three Stooges were renowned for their slapstick comedy.
# 20. Stand-up: A form of comedy delivery in which a comic entertains an audience with jokes and humorous stories. A stand-up comedian may employ one or more of the types of humor described here.
#
# then create a title from the abstract for a reserch paper which should not be funny is rather boring and just descriptive.
#
# then I want you to create a json output which will have abstract, original_title, Created_title, and humor category.

# %%
import requests
import json
import pandas as pd
import time
from tqdm import tqdm

# Load the CSV file containing the data
df = pd.read_csv('merged_humor_data_label_1.csv')

# Define API parameters
MODEL = "openrouter/quasar-alpha"
SITE_URL = "https://yoursite.com"  # Replace with your actual site URL
SITE_NAME = "Humor Classification Research"  # Replace with your project name

# Create empty lists to store results
results = []

# Function to make API request
def make_api_request(abstract, title):
    prompt = f"""I need you to perform a task based on this abstract and title. First, categorize the title in one of the 20 humor categories:

1. Anecdotal: Named after the word anecdote (which stems from the Greek term meaning "unpublished"); refers to comic personal stories that may be true or partly true but embellished.
2. Blue: Also called off-color, or risque (from the French word for "to risk"); relies on impropriety or indecency for comic effect.
3. Burlesque: Ridicules by imitating with caricature, or exaggerated characterization.
4. Dark/Gallows/Morbid: Grim or depressing humor dealing with misfortune and/or death and with a pessimistic outlook.
5. Deadpan/Dry: Delivered with an impassive, expressionless, matter-of-fact presentation.
6. Droll: From the Dutch word meaning "imp"; utilizes capricious or eccentric humor.
7. Epigrammatic: Humor consisting of a witty saying.
8. Farcical: Comedy based on improbable coincidences and with satirical elements.
9. High/highbrow: Humor pertaining to cultured, sophisticated themes.
10. Hyperbolic: Comic presentation marked by extravagant exaggeration and outsized characterization.
11. Ironic: Humor involving incongruity and discordance with norms, in which the intended meaning is opposite, or nearly opposite, to the literal meaning.
12. Juvenile/sophomoric: Humor involving childish themes such as pranks, name-calling, and other immature behavior.
13. Mordant: Caustic or biting humor.
14. Parodic: Comic imitation often intended to ridicule an author, an artistic endeavor, or a genre.
15. Satirical: Humor that mocks human weaknesses or aspects of society.
16. Screwball: Akin to farce in that it deals with unlikely situations and responses to those situations.
17. Self-deprecating: Humor in which performers target themselves and their foibles or misfortunes for comic effect.
18. Situational: Humor arising out of quotidian situations.
19. Slapstick: Comedy in which mock violence and simulated bodily harm are staged for comic effect.
20. Stand-up: A form of comedy delivery in which a comic entertains an audience with jokes and humorous stories.

Then create a title from the abstract for a research paper which should not be funny but rather boring and just descriptive.

Then create a JSON output with abstract, original_title, created_title, and humor_category.

Abstract: {abstract}
Original Title: {title}"""

    try:
        response = requests.post(
            url="https://openrouter.ai/api/v1/chat/completions",
            headers={
                "Authorization": f"Bearer {OPENROUTER_API_KEY}",
                "Content-Type": "application/json",
                "HTTP-Referer": SITE_URL,
                "X-Title": SITE_NAME,
            },
            data=json.dumps({
                "model": MODEL,
                "messages": [
                    {
                        "role": "user",
                        "content": prompt
                    }
                ]
            }),
            timeout=20  # Set a reasonable timeout
        )
        
        # Check response status
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error: API returned status code {response.status_code}")
            print(f"Response content: {response.text}")
            return None
            
    except Exception as e:
        print(f"Exception occurred: {e}")
        return None

# Process each row in the dataframe
# Use a smaller subset for testing first
sample_size = 10  # Adjust this number based on your needs
processed_data = []

for index, row in tqdm(df.head(sample_size).iterrows(), total=min(sample_size, len(df))):
    abstract = row['abstract']
    title = row['title']
    
    print(f"Processing item {index+1}/{sample_size}")
    
    # Make API request
    api_response = make_api_request(abstract, title)
    
    if api_response and 'choices' in api_response and len(api_response['choices']) > 0:
        # Extract the response content
        response_content = api_response['choices'][0]['message']['content']
        
        # Try to extract JSON from the response
        try:
            # Find JSON content in the response
            start_idx = response_content.find('{')
            end_idx = response_content.rfind('}') + 1
            
            if start_idx >= 0 and end_idx > start_idx:
                json_str = response_content[start_idx:end_idx]
                result = json.loads(json_str)
                
                # Add to results
                processed_data.append({
                    'abstract': result.get('abstract', ''),
                    'original_title': result.get('original_title', ''),
                    'created_title': result.get('created_title', ''),
                    'humor_category': result.get('humor_category', '')
                })
                
                print(f"Successfully processed item {index+1}")
            else:
                print(f"No JSON found in response for item {index+1}")
        except json.JSONDecodeError as e:
            print(f"Failed to parse JSON for item {index+1}: {e}")
            print(f"Response content: {response_content}")
    else:
        print(f"No valid response for item {index+1}")
    
    # Add a small delay to avoid rate limiting
    time.sleep(2)

# Create dataframe from processed data
results_df = pd.DataFrame(processed_data)

# Save to CSV
output_file = 'humor_classification_results.csv'
results_df.to_csv(output_file, index=False)

print(f"Processing complete. Results saved to {output_file}")

# Display the first few results
results_df.head()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Processing item 1/10
# Successfully processed item 1
#  10%|█         | 1/10 [00:04<00:40,  4.47s/it]
# Processing item 2/10
# Successfully processed item 2
#  20%|██        | 2/10 [00:08<00:34,  4.30s/it]
# Processing item 3/10
# Successfully processed item 3
#  30%|███       | 3/10 [00:12<00:29,  4.16s/it]
# Processing item 4/10
# Successfully processed item 4
#  40%|████      | 4/10 [00:17<00:26,  4.34s/it]
# Processing item 5/10
# Successfully processed item 5
#  50%|█████     | 5/10 [00:21<00:21,  4.29s/it]
# Processing item 6/10
# Successfully processed item 6
#  60%|██████    | 6/10 [00:25<00:16,  4.22s/it]
# Processing item 7/10
# Successfully processed item 7
#  70%|███████   | 7/10 [00:30<00:13,  4.55s/it]
# Processing item 8/10
# Successfully processed item 8
#  80%|████████  | 8/10 [00:36<00:10,  5.02s/it]
# Processing item 9/10
# Successfully processed item 9
#  90%|█████████ | 9/10 [00:42<00:05,  5.12s/it]
# Processing item 10/10
# Successfully processed item 10
# 100%|██████████| 10/10 [00:46<00:00,  4.64s/it]
# Processing complete. Results saved to humor_classification_results.csv
#                                             abstract  \
# 0  Pre-trained language models (LMs) may perpetua...
# 1  We propose an approach to adjective-noun compo...
# 2  In order to determine argument structure in te...
# 3  Activation functions play a crucial role in ne...
# 4  Corpus query systems exist to address the mult...
#
#                                       original_title  \
# 0  "You are grounded!": Latent Name Artifacts in ...
# 1  Nouns are Vectors, Adjectives are Matrices: Re...
# 2  Here's My Point: Joint Pointer Architecture fo...
# 3  Is it Time to Swish? Comparing Deep Learning A...
# 4  To Boldly Query What No One Has Annotated Befo...
#
#                                        created_title humor_category
# 0  An Analysis of Bias and Name-Related Artifacts...         Ironic
# 1  A Data-Driven Method for Representing Adjectiv...         Ironic
# 2  A Joint Neural Network Model for Link Extracti...   Epigrammatic
# 3  A Comprehensive Benchmarking of 21 Activation ...   Epigrammatic
# 4  A Survey of Corpus Query Systems and Their Dev...        Parodic

# %%
import requests
import json
import pandas as pd
import time
import os
from tqdm.notebook import tqdm  # Use tqdm.notebook for Jupyter notebooks

# Load the CSV file containing the data
df = pd.read_csv('merged_humor_data_label_1.csv')
total_rows = len(df)
print(f"Total rows in dataset: {total_rows}")

# Define API parameters
OPENROUTER_API_KEY = "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"
MODEL = "openrouter/quasar-alpha"
SITE_URL = "https://yoursite.com"  # Replace with your actual site URL
SITE_NAME = "Humor Classification Research"  # Replace with your project name

# Output file path
output_file = 'humor_classification_results.csv'

# Batch size for saving
BATCH_SIZE = 10

# Check if results file already exists to resume
start_index = 10
if os.path.exists(output_file):
    existing_results = pd.read_csv(output_file)
    if len(existing_results) > 0:
        # Find the highest processed index to resume from there
        if 'original_index' in existing_results.columns:
            start_index = existing_results['original_index'].max() + 1
        else:
            start_index = len(existing_results)
        print(f"Resuming from index {start_index}")

# Function to make API request
def make_api_request(abstract, title, max_retries=3, retry_delay=5):
    prompt = f"""I need you to perform a task based on this abstract and title. First, categorize the title in one of the 20 humor categories:

1. Anecdotal: Named after the word anecdote (which stems from the Greek term meaning "unpublished"); refers to comic personal stories that may be true or partly true but embellished.
2. Blue: Also called off-color, or risque (from the French word for "to risk"); relies on impropriety or indecency for comic effect.
3. Burlesque: Ridicules by imitating with caricature, or exaggerated characterization.
4. Dark/Gallows/Morbid: Grim or depressing humor dealing with misfortune and/or death and with a pessimistic outlook.
5. Deadpan/Dry: Delivered with an impassive, expressionless, matter-of-fact presentation.
6. Droll: From the Dutch word meaning "imp"; utilizes capricious or eccentric humor.
7. Epigrammatic: Humor consisting of a witty saying.
8. Farcical: Comedy based on improbable coincidences and with satirical elements.
9. High/highbrow: Humor pertaining to cultured, sophisticated themes.
10. Hyperbolic: Comic presentation marked by extravagant exaggeration and outsized characterization.
11. Ironic: Humor involving incongruity and discordance with norms, in which the intended meaning is opposite, or nearly opposite, to the literal meaning.
12. Juvenile/sophomoric: Humor involving childish themes such as pranks, name-calling, and other immature behavior.
13. Mordant: Caustic or biting humor.
14. Parodic: Comic imitation often intended to ridicule an author, an artistic endeavor, or a genre.
15. Satirical: Humor that mocks human weaknesses or aspects of society.
16. Screwball: Akin to farce in that it deals with unlikely situations and responses to those situations.
17. Self-deprecating: Humor in which performers target themselves and their foibles or misfortunes for comic effect.
18. Situational: Humor arising out of quotidian situations.
19. Slapstick: Comedy in which mock violence and simulated bodily harm are staged for comic effect.
20. Stand-up: A form of comedy delivery in which a comic entertains an audience with jokes and humorous stories.

Then create a title from the abstract for a research paper which should not be funny but rather boring and just descriptive.

Please provide your response in the following JSON format only:
{{
  "abstract": "{abstract}",
  "original_title": "{title}",
  "created_title": "Your created descriptive title here",
  "humor_category": "Selected category from the list above"
}}

Abstract: {abstract}
Original Title: {title}"""

    for attempt in range(max_retries):
        try:
            response = requests.post(
                url="https://openrouter.ai/api/v1/chat/completions",
                headers={
                    "Authorization": f"Bearer {OPENROUTER_API_KEY}",
                    "Content-Type": "application/json",
                    "HTTP-Referer": SITE_URL,
                    "X-Title": SITE_NAME,
                },
                data=json.dumps({
                    "model": MODEL,
                    "messages": [
                        {
                            "role": "user",
                            "content": prompt
                        }
                    ]
                }),
                timeout=60  # Increased timeout for larger abstracts
            )
            
            # Check response status
            if response.status_code == 200:
                return response.json()
            elif response.status_code == 429:  # Rate limit error
                print(f"Rate limit hit. Attempt {attempt+1}/{max_retries}. Waiting {retry_delay} seconds...")
                time.sleep(retry_delay)
                retry_delay *= 2  # Exponential backoff
            else:
                print(f"Error: API returned status code {response.status_code}")
                print(f"Response content: {response.text}")
                time.sleep(retry_delay)
                
        except Exception as e:
            print(f"Exception occurred (attempt {attempt+1}/{max_retries}): {e}")
            time.sleep(retry_delay)
    
    return None  # Return None if all retries failed

# Function to extract JSON from response content
def extract_json(response_content):
    try:
        # First try direct JSON parsing (in case the whole response is a valid JSON)
        return json.loads(response_content)
    except json.JSONDecodeError:
        # If that fails, try to extract JSON portion
        start_idx = response_content.find('{')
        end_idx = response_content.rfind('}') + 1
        
        if start_idx >= 0 and end_idx > start_idx:
            json_str = response_content[start_idx:end_idx]
            try:
                return json.loads(json_str)
            except json.JSONDecodeError as e:
                print(f"Failed to parse extracted JSON: {e}")
                return None
        else:
            print("No JSON content found in response")
            return None

# Process data in batches
def process_in_batches(start_idx, end_idx=None, batch_size=BATCH_SIZE):
    if end_idx is None:
        end_idx = total_rows
    
    # Load existing results if any
    all_results = []
    if os.path.exists(output_file):
        existing_df = pd.read_csv(output_file)
        all_results = existing_df.to_dict('records')
        print(f"Loaded {len(all_results)} existing results")
    
    batch_results = []
    
    # Create progress bar
    for idx in tqdm(range(start_idx, min(end_idx, total_rows)), desc="Processing items"):
        row = df.iloc[idx]
        abstract = str(row['abstract'])
        title = str(row['title'])
        
        print(f"\nProcessing item {idx+1}/{total_rows} - Title: {title[:50]}...")
        
        # Make API request
        api_response = make_api_request(abstract, title)
        
        if api_response and 'choices' in api_response and len(api_response['choices']) > 0:
            # Extract the response content
            response_content = api_response['choices'][0]['message']['content']
            
            # Try to extract JSON from the response
            result = extract_json(response_content)
            
            if result:
                # Add original index for reference
                result['original_index'] = idx
                
                # Validate the result has all required fields
                if all(k in result for k in ['abstract', 'original_title', 'created_title', 'humor_category']):
                    batch_results.append(result)
                    print(f"Successfully processed item {idx+1} - Category: {result['humor_category']}")
                else:
                    print(f"Missing fields in result: {result.keys()}")
            else:
                print(f"Failed to extract JSON for item {idx+1}")
                print(f"Response content: {response_content[:200]}...")  # Print first 200 chars
        else:
            print(f"No valid response for item {idx+1}")
        
        # Save results after each batch
        if len(batch_results) >= batch_size:
            # Append batch results to all results
            all_results.extend(batch_results)
            
            # Save to CSV
            pd.DataFrame(all_results).to_csv(output_file, index=False)
            print(f"Saved batch results. Total processed so far: {len(all_results)}")
            
            # Clear batch results for next batch
            batch_results = []
        
        # Add a small delay to avoid rate limiting
        time.sleep(2)
    
    # Save any remaining results
    if batch_results:
        all_results.extend(batch_results)
        pd.DataFrame(all_results).to_csv(output_file, index=False)
        print(f"Saved final batch. Total processed: {len(all_results)}")
    
    return all_results

# Main execution
if __name__ == "__main__":
    try:
        # Define how many items to process (for testing, use a small number)
        # For full processing, set this to None
        max_items = None  # Process all items
        
        # Calculate end index based on start_index and max_items
        end_idx = None if max_items is None else start_index + max_items
        
        print(f"Starting processing from index {start_index} to {end_idx if end_idx else 'end'}")
        
        # Process data in batches
        results = process_in_batches(start_index, end_idx)
        
        print(f"\nProcessing complete. Total results: {len(results)}")
        
        # Display analysis of results
        results_df = pd.DataFrame(results)
        
        if not results_df.empty:
            # Show distribution of humor categories
            print("\nHumor Category Distribution:")
            category_counts = results_df['humor_category'].value_counts()
            for category, count in category_counts.items():
                print(f"  {category}: {count} ({count/len(results_df)*100:.1f}%)")
            
            # Display the first few results
            print("\nSample of results:")
            print(results_df[['original_title', 'created_title', 'humor_category']].head())
        
    except Exception as e:
        print(f"An error occurred during execution: {e}")
# Out:
# Total rows in dataset: 488
# Resuming from index 10
# Starting processing from index 10 to end
# Loaded 10 existing results
# Processing items:   0%|          | 0/478 [00:00<?, ?it/s]
# Processing item 11/488 - Title: Are You Sure That This Happened? Assessing the Fac...
# Successfully processed item 11 - Category: Ironic
#
# Processing item 12/488 - Title: What's in a Summary? Laying the Groundwork for Adv...
# Successfully processed item 12 - Category: Epigrammatic
#
# Processing item 13/488 - Title: How low is too low? A monolingual take on lemmatis...
# Successfully processed item 13 - Category: Ironic
#
# Processing item 14/488 - Title: What's the Trouble: Automatically Identifying Prob...
# Successfully processed item 14 - Category: Epigrammatic
#
# Processing item 15/488 - Title: Fixed That for You: Generating Contrastive Claims ...
# Successfully processed item 15 - Category: Epigrammatic
#
# Processing item 16/488 - Title: Who, What, When, Where, Why? Comparing Multiple Ap...
# Successfully processed item 16 - Category: Epigrammatic
#
# Processing item 17/488 - Title: Does My Rebuttal Matter? Insights from a Major NLP...
# Successfully processed item 17 - Category: Ironic
#
# Processing item 18/488 - Title: MangaGAN: Unpaired Photo-to-Manga Translation Base...
# Successfully processed item 18 - Category: High/highbrow
#
# Processing item 19/488 - Title: Working Hard or Hardly Working: Challenges of Inte...
# Successfully processed item 19 - Category: Ironic
#
# Processing item 20/488 - Title: GhostBERT: Generate More Features with Cheap Opera...
# Successfully processed item 20 - Category: Parodic
# Saved batch results. Total processed so far: 20
#
# Processing item 21/488 - Title: Don't understand a measure? Learn it: Structured P...
# Successfully processed item 21 - Category: Epigrammatic
#
# Processing item 22/488 - Title: It's Not Just Size That Matters: Small Language Mo...
# Successfully processed item 22 - Category: Ironic
#
# Processing item 23/488 - Title: OoMMix: Out-of-manifold Regularization in Contextu...
# Successfully processed item 23 - Category: High/highbrow
#
# Processing item 24/488 - Title: Coreference or Not: A Twin Model for Coreference R...
# Successfully processed item 24 - Category: Epigrammatic
#
# Processing item 25/488 - Title: A Primer in BERTology: What We Know About How BERT...
# Successfully processed item 25 - Category: High/highbrow
#
# Processing item 26/488 - Title: Good for Misconceived Reasons: An Empirical Revisi...
# Successfully processed item 26 - Category: Ironic
#
# Processing item 27/488 - Title: AMPERSAND: Argument Mining for PERSuAsive oNline D...
# Successfully processed item 27 - Category: Parodic
#
# Processing item 28/488 - Title: Errudite: Scalable, Reproducible, and Testable Err...
# Successfully processed item 28 - Category: Epigrammatic
#
# Processing item 29/488 - Title: Asking the Right Questions to the Right Users: Act...
# Successfully processed item 29 - Category: Epigrammatic
#
# Processing item 30/488 - Title: Watch, Listen, and Describe: Globally and Locally ...
# Successfully processed item 30 - Category: Epigrammatic
# Saved batch results. Total processed so far: 30
#
# Processing item 31/488 - Title: Read and Reason with MuSeRC and RuCoS: Datasets fo...
# Successfully processed item 31 - Category: Epigrammatic
#
# Processing item 32/488 - Title: Generate Your Counterfactuals: Towards Controlled ...
# Successfully processed item 32 - Category: Epigrammatic
#
# Processing item 33/488 - Title: Small but Mighty: New Benchmarks for Split and Rep...
# Successfully processed item 33 - Category: Hyperbolic
#
# Processing item 34/488 - Title: What You Say and How You Say it: Joint Modeling of...
# Successfully processed item 34 - Category: Epigrammatic
#
# Processing item 35/488 - Title: Don't Take the Easy Way Out: Ensemble Based Method...
# Successfully processed item 35 - Category: Epigrammatic
#
# Processing item 36/488 - Title: Predictive inference is free with the jackknife+-a...
# Successfully processed item 36 - Category: Epigrammatic
#
# Processing item 37/488 - Title: "I Thou Thee, Thou Traitor": Predicting Formal vs....
# Successfully processed item 37 - Category: Parodic
#
# Processing item 38/488 - Title: SphereRE: Distinguishing Lexical Relations with Hy...
# Successfully processed item 38 - Category: High/highbrow
#
# Processing item 39/488 - Title: Who caught a cold ? - Identifying the subject of a...
# Successfully processed item 39 - Category: Ironic
#
# Processing item 40/488 - Title: Gender in Danger? Evaluating Speech Translation Te...
# Successfully processed item 40 - Category: Ironic
# Saved batch results. Total processed so far: 40
#
# Processing item 41/488 - Title: Would you Rather? A New Benchmark for Learning Mac...
# Successfully processed item 41 - Category: Anecdotal
#
# Processing item 42/488 - Title: Don't count, predict! A systematic comparison of c...
# Successfully processed item 42 - Category: Epigrammatic
#
# Processing item 43/488 - Title: Don't 'Have a Clue'? Unsupervised Co-Learning of D...
# Successfully processed item 43 - Category: Ironic
#
# Processing item 44/488 - Title: Detect All Abuse! Toward Universal Abusive Languag...
# Successfully processed item 44 - Category: Hyperbolic
#
# Processing item 45/488 - Title: Frivolous Units: Wider Networks Are Not Really Tha...
# Successfully processed item 45 - Category: Ironic
#
# Processing item 46/488 - Title: Crush Optimism with Pessimism: Structured Bandits ...
# Successfully processed item 46 - Category: Ironic
#
# Processing item 47/488 - Title: Making "fetch" happen: The influence of social and...
# Successfully processed item 47 - Category: Parodic
#
# Processing item 48/488 - Title: Is an Image Worth More than a Thousand Words? On t...
# Successfully processed item 48 - Category: Ironic
#
# Processing item 49/488 - Title: Don't paraphrase, detect! Rapid and Effective Data...
# Successfully processed item 49 - Category: Epigrammatic
#
# Processing item 50/488 - Title: Sprite: Generalizing Topic Models with Structured ...
# Successfully processed item 50 - Category: Epigrammatic
# Saved batch results. Total processed so far: 50
#
# Processing item 51/488 - Title: Not All Claims are Created Equal: Choosing the Rig...
# Successfully processed item 51 - Category: Ironic
#
# Processing item 52/488 - Title: The Galactic Dependencies Treebanks: Getting More ...
# Successfully processed item 52 - Category: Hyperbolic
#
# Processing item 53/488 - Title: Who Is Speaking to Whom? Learning to Identify Utte...
# Successfully processed item 53 - Category: Epigrammatic
#
# Processing item 54/488 - Title: PhotoChat: A Human-Human Dialogue Dataset With Pho...
# Successfully processed item 54 - Category: Descriptive titles like this are straightforward and not humorous. The original title contains an informal, playful tone with the term 'PhotoChat', which personifies the dataset, mildly bordering on 'Droll' (6). However, since the focus is classification, the best match is 'Droll'.
#
# Processing item 55/488 - Title: How coherent are neural models of coherence?...
# Successfully processed item 55 - Category: Ironic
#
# Processing item 56/488 - Title: To Relieve Your Headache of Training an MRF, Take ...
# Successfully processed item 56 - Category: Ironic
#
# Processing item 57/488 - Title: Is It the Right Answer? Exploiting Web Redundancy ...
# Successfully processed item 57 - Category: Ironic
#
# Processing item 58/488 - Title: Thumbs up? Sentiment Classification using Machine ...
# Successfully processed item 58 - Category: Ironic
#
# Processing item 59/488 - Title: Membership Inference Attacks on Sequence-to-Sequen...
# Successfully processed item 59 - Category: Ironic
#
# Processing item 60/488 - Title: Yes, we can! Mining Arguments in 50 Years of US Pr...
# Successfully processed item 60 - Category: Epigrammatic
# Saved batch results. Total processed so far: 60
#
# Processing item 61/488 - Title: Coulomb GANs: Provably Optimal Nash Equilibria via...
# Successfully processed item 61 - Category: High/highbrow
#
# Processing item 62/488 - Title: No Noun Phrase Left Behind: Detecting and Typing U...
# Successfully processed item 62 - Category: Parodic
#
# Processing item 63/488 - Title: Supervised Seeded Iterated Learning for Interactiv...
# Successfully processed item 63 - Category: High/highbrow
#
# Processing item 64/488 - Title: VerbOcean: Mining the Web for Fine-Grained Semanti...
# Successfully processed item 64 - Category: Parodic
#
# Processing item 65/488 - Title: Who's (Really) the Boss? Perception of Situational...
# Successfully processed item 65 - Category: Ironic
#
# Processing item 66/488 - Title: Who Can Win a Single-Elimination Tournament?...
# Successfully processed item 66 - Category: Epigrammatic
#
# Processing item 67/488 - Title: Asking too much? The rhetorical role of questions ...
# Successfully processed item 67 - Category: Ironic
#
# Processing item 68/488 - Title: "i have a feeling trump will win.....................
# Successfully processed item 68 - Category: Anecdotal
#
# Processing item 69/488 - Title: Liberty or Depth: Deep Bayesian Neural Nets Do Not...
# Successfully processed item 69 - Category: Epigrammatic
#
# Processing item 70/488 - Title: That's So Annoying!!!: A Lexical and Frame-Semanti...
# Successfully processed item 70 - Category: Anecdotal
# Saved batch results. Total processed so far: 70
#
# Processing item 71/488 - Title: Who is Who and What is What: Experiments in Cross-...
# Successfully processed item 71 - Category: Epigrammatic
#
# Processing item 72/488 - Title: How to Motivate Your Dragon: Teaching Goal-Driven ...
# Successfully processed item 72 - Category: Parodic
#
# Processing item 73/488 - Title: SOLAR: Sparse Orthogonal Learned and Random Embedd...
# Successfully processed item 73 - Category: Epigrammatic
#
# Processing item 74/488 - Title: BERT Knows Punta Cana is not just beautiful, it's ...
# Successfully processed item 74 - Category: Ironic
#
# Processing item 75/488 - Title: What's Yours and What's Mine: Determining Intellec...
# Successfully processed item 75 - Category: Epigrammatic
#
# Processing item 76/488 - Title: What's Missing: A Knowledge Gap Guided Approach fo...
# Successfully processed item 76 - Category: Ironic
#
# Processing item 77/488 - Title: What's in a Name? Reducing Bias in Bios without Ac...
# Successfully processed item 77 - Category: Ironic
#
# Processing item 78/488 - Title: PATTY: A Taxonomy of Relational Patterns with Sema...
# Successfully processed item 78 - Category: High/highbrow
#
# Processing item 79/488 - Title: TET-GAN: Text Effects Transfer via Stylization and...
# Successfully processed item 79 - Category: High/highbrow
#
# Processing item 80/488 - Title: Cross-lingual Argumentation Mining: Machine Transl...
# Successfully processed item 80 - Category: Hyperbolic
# Saved batch results. Total processed so far: 80
#
# Processing item 81/488 - Title: Watch, Try, Learn: Meta-Learning from Demonstratio...
# Successfully processed item 81 - Category: Epigrammatic
#
# Processing item 82/488 - Title: PISA: A measure of Preference In Selection of Argu...
# Successfully processed item 82 - Category: Epigrammatic
#
# Processing item 83/488 - Title: Now, Where Was I? Resumption Strategies for an In-...
# Successfully processed item 83 - Category: Anecdotal
#
# Processing item 84/488 - Title: Will You "Reconsume" the Near Past? Fast Predictio...
# Successfully processed item 84 - Category: Ironic
#
# Processing item 85/488 - Title: NYTWIT: A Dataset of Novel Words in the New York T...
# Successfully processed item 85 - Category: Epigrammatic
#
# Processing item 86/488 - Title: Spot the Odd Man Out: Exploring the Associative Po...
# Successfully processed item 86 - Category: Ironic
#
# Processing item 87/488 - Title: Get Your Vitamin C! Robust Fact Verification with ...
# Successfully processed item 87 - Category: Epigrammatic
#
# Processing item 88/488 - Title: Chinese Pinyin Aided IME, Input What You Have Not ...
# Successfully processed item 88 - Category: Ironic
#
# Processing item 89/488 - Title: Men Are Elected, Women Are Married: Events Gender ...
# Successfully processed item 89 - Category: Ironic
#
# Processing item 90/488 - Title: Back to Basics for Monolingual Alignment: Exploiti...
# Successfully processed item 90 - Category: Ironic
# Saved batch results. Total processed so far: 90
#
# Processing item 91/488 - Title: Overconfidence or Paranoia? Search in Imperfect-In...
# Successfully processed item 91 - Category: Epigrammatic
#
# Processing item 92/488 - Title: Why Didn't You Listen to Me? Comparing User Contro...
# Successfully processed item 92 - Category: Ironic
#
# Processing item 93/488 - Title: Why Read if You Can Scan? Trigger Scoping Strategy...
# Successfully processed item 93 - Category: Ironic
#
# Processing item 94/488 - Title: Charmanteau: Character Embedding Models For Portma...
# Successfully processed item 94 - Category: Parodic
#
# Processing item 95/488 - Title: Don't Patronize Me! An Annotated Dataset with Patr...
# Successfully processed item 95 - Category: Epigrammatic
#
# Processing item 96/488 - Title: Picasso, Matisse, or a Fake? Automated Analysis of...
# Successfully processed item 96 - Category: Ironic
#
# Processing item 97/488 - Title: HOLMS: Alternative Summary Evaluation with Large L...
# Successfully processed item 97 - Category: Epigrammatic
#
# Processing item 98/488 - Title: Do You Know That Florence Is Packed with Visitors?...
# Successfully processed item 98 - Category: Epigrammatic
#
# Processing item 99/488 - Title: LeMoNADe: Learned Motif and Neuronal Assembly Dete...
# Successfully processed item 99 - Category: Epigrammatic
#
# Processing item 100/488 - Title: Outta Control: Laws of Semantic Change and Inheren...
# Successfully processed item 100 - Category: Ironic
# Saved batch results. Total processed so far: 100
#
# Processing item 101/488 - Title: You've Got Answers: Towards Personalized Models fo...
# Successfully processed item 101 - Category: Parodic
#
# Processing item 102/488 - Title: Don't Use English Dev: On the Zero-Shot Cross-Ling...
# Successfully processed item 102 - Category: Epigrammatic
#
# Processing item 103/488 - Title: MelBERT: Metaphor Detection via Contextualized Lat...
# Successfully processed item 103 - Category: High/highbrow
#
# Processing item 104/488 - Title: Treat us like the sequences we are: Prepositional ...
# Successfully processed item 104 - Category: Personification with a light, ironic tone—primarily Ironic
#
# Processing item 105/488 - Title: Did they answer? Subjective acts and intents in co...
# Successfully processed item 105 - Category: Ironic
#
# Processing item 106/488 - Title: SPECTER: Document-level Representation Learning us...
# Successfully processed item 106 - Category: High/highbrow
#
# Processing item 107/488 - Title: Apples to Apples: Learning Semantics of Common Ent...
# Successfully processed item 107 - Category: Ironic
#
# Processing item 108/488 - Title: Does GIZA++ Make Search Errors?...
# Successfully processed item 108 - Category: Ironic
#
# Processing item 109/488 - Title: That's Not What I Meant! Using Parsers to Avoid St...
# Successfully processed item 109 - Category: Ironic
#
# Processing item 110/488 - Title: Is this a wampimuk? Cross-modal mapping between di...
# Successfully processed item 110 - Category: Situational
# Saved batch results. Total processed so far: 110
#
# Processing item 111/488 - Title: Cheap and Fast - But is it Good? Evaluating Non-Ex...
# Successfully processed item 111 - Category: Ironic
#
# Processing item 112/488 - Title: DeepMath - Deep Sequence Models for Premise Select...
# Successfully processed item 112 - Category: Epigrammatic
#
# Processing item 113/488 - Title: Mind the Gap: Cake Cutting With Separation...
# Successfully processed item 113 - Category: Epigrammatic
#
# Processing item 114/488 - Title: AdaFuse: Adaptive Temporal Fusion Network for Effi...
# Successfully processed item 114 - Category: High/highbrow
#
# Processing item 115/488 - Title: Let’s be Honest: An Optimal No-Regret Framework fo...
# Successfully processed item 115 - Category: Epigrammatic
#
# Processing item 116/488 - Title: Devign: Effective Vulnerability Identification by ...
# Successfully processed item 116 - Category: High/highbrow
#
# Processing item 117/488 - Title: How Far Does BERT Look At: Distance-based Clusteri...
# Successfully processed item 117 - Category: Ironic
#
# Processing item 118/488 - Title: SuperLoss: A Generic Loss for Robust Curriculum Le...
# Successfully processed item 118 - Category: Hyperbolic
#
# Processing item 119/488 - Title: Explore no more: Improved high-probability regret ...
# Successfully processed item 119 - Category: Epigrammatic
#
# Processing item 120/488 - Title: Mind the GAP: A Balanced Corpus of Gendered Ambigu...
# Successfully processed item 120 - Category: Epigrammatic
# Saved batch results. Total processed so far: 120
#
# Processing item 121/488 - Title: PIPPS: Flexible Model-Based Policy Search Robust t...
# Successfully processed item 121 - Category: Hyperbolic
#
# Processing item 122/488 - Title: Nonsense!: Quality Control via Two-Step Reason Sel...
# Successfully processed item 122 - Category: Epigrammatic
#
# Processing item 123/488 - Title: The More Antecedents, the Merrier: Resolving Multi...
# Successfully processed item 123 - Category: Ironic
#
# Processing item 124/488 - Title: Fatal or not? Finding errors that lead to dialogue...
# Successfully processed item 124 - Category: Dark/Gallows/Morbid
#
# Processing item 125/488 - Title: Non-Native Users in the Let's Go!! Spoken Dialogue...
# Successfully processed item 125 - Category: Hyperbolic
#
# Processing item 126/488 - Title: Free the Plural: Unrestricted Split-Antecedent Ana...
# Successfully processed item 126 - Category: Epigrammatic
#
# Processing item 127/488 - Title: ENTRUST: Argument Reframing with Language Models a...
# Successfully processed item 127 - Category: Epigrammatic
#
# Processing item 128/488 - Title: Attractive People: Assembling Loose-Limbed Models ...
# Successfully processed item 128 - Category: Ironic
#
# Processing item 129/488 - Title: BabelRelate! A Joint Multilingual Approach to Comp...
# Successfully processed item 129 - Category: Epigrammatic
#
# Processing item 130/488 - Title: Hold me tight! Influence of discriminative feature...
# Successfully processed item 130 - Category: Ironic
# Saved batch results. Total processed so far: 130
#
# Processing item 131/488 - Title: Language in a (Search) Box: Grounding Language Lea...
# Successfully processed item 131 - Category: Ironic
#
# Processing item 132/488 - Title: Twitter Catches The Flu: Detecting Influenza Epide...
# Successfully processed item 132 - Category: Ironic
#
# Processing item 133/488 - Title: To BERT or Not to BERT: Comparing Task-specific an...
# Successfully processed item 133 - Category: Parodic
#
# Processing item 134/488 - Title: How Good is Your Tokenizer? On the Monolingual Per...
# Successfully processed item 134 - Category: Epigrammatic
#
# Processing item 135/488 - Title: Different Structures for Evaluating Answers to Com...
# Successfully processed item 135 - Category: Ironic
#
# Processing item 136/488 - Title: Humor in Word Embeddings: Cockamamie Gobbledegook ...
# Successfully processed item 136 - Category: Burlesque
#
# Processing item 137/488 - Title: Stereopagnosia: Fooling Stereo Networks with Adver...
# Successfully processed item 137 - Category: Parodic
#
# Processing item 138/488 - Title: All-but-the-Top: Simple and Effective Postprocessi...
# Successfully processed item 138 - Category: Ironic
#
# Processing item 139/488 - Title: Answerer in Questioner's Mind: Information Theoret...
# Successfully processed item 139 - Category: High/highbrow
#
# Processing item 140/488 - Title: Curse or Redemption? How Data Heterogeneity Affect...
# Successfully processed item 140 - Category: Ironic
# Saved batch results. Total processed so far: 140
#
# Processing item 141/488 - Title: Something's Brewing! Early Prediction of Controver...
# Successfully processed item 141 - Category: Epigrammatic
#
# Processing item 142/488 - Title: From which world is your graph...
# Successfully processed item 142 - Category: Ironic
#
# Processing item 143/488 - Title: Diagnose Like A Pathologist: Weakly-Supervised Pat...
# Successfully processed item 143 - Category: Parodic
#
# Processing item 144/488 - Title: The Usual Suspects? Reassessing Blame for VAE Post...
# Successfully processed item 144 - Category: Ironic
#
# Processing item 145/488 - Title: All That's 'Human' Is Not Gold: Evaluating Human E...
# Successfully processed item 145 - Category: Ironic
#
# Processing item 146/488 - Title: Erdos Goes Neural: an Unsupervised Learning Framew...
# Successfully processed item 146 - Category: Parodic
#
# Processing item 147/488 - Title: One model, two languages: training bilingual parse...
# Successfully processed item 147 - Category: Epigrammatic
#
# Processing item 148/488 - Title: Courteously Yours: Inducing courteous behavior in ...
# Successfully processed item 148 - Category: Epigrammatic
#
# Processing item 149/488 - Title: Doing Good or Doing Right? Exploring the Weakness ...
# Successfully processed item 149 - Category: Ironic
#
# Processing item 150/488 - Title: Brighter than Gold: Figurative Language in User Ge...
# Successfully processed item 150 - Category: Epigrammatic
# Saved batch results. Total processed so far: 150
#
# Processing item 151/488 - Title: Translate and Label! An Encoder-Decoder Approach f...
# Successfully processed item 151 - Category: Epigrammatic
#
# Processing item 152/488 - Title: Blow the Dog Whistle: A Chinese Dataset for Cant U...
# Successfully processed item 152 - Category: Ironic
#
# Processing item 153/488 - Title: ABCNN: Attention-Based Convolutional Neural Networ...
# Successfully processed item 153 - Category: High/highbrow
#
# Processing item 154/488 - Title: Word Salad: Relating Food Prices and Descriptions...
# Successfully processed item 154 - Category: Ironic
#
# Processing item 155/488 - Title: Finding the Storyteller: Automatic Spoiler Tagging...
# Successfully processed item 155 - Category: Metaphorical and personifying titles like 'Finding the Storyteller' generally fall under the Ironic category, as they play on expectations by anthropomorphizing or using incongruity with the literal task description. So, the humor category is 'Ironic'.
#
# Processing item 156/488 - Title: Don't Neglect the Obvious: On the Role of Unambigu...
# Successfully processed item 156 - Category: Ironic
#
# Processing item 157/488 - Title: Powergrading: a Clustering Approach to Amplify Hum...
# Successfully processed item 157 - Category: Epigrammatic
#
# Processing item 158/488 - Title: Little Is Much: Bridging Cross-Platform Behaviors ...
# Successfully processed item 158 - Category: Ironic
#
# Processing item 159/488 - Title: Quick and (not so) Dirty: Unsupervised Selection o...
# Successfully processed item 159 - Category: Ironic
#
# Processing item 160/488 - Title: Jointly Learning to Parse and Perceive: Connecting...
# Successfully processed item 160 - Category: High/highbrow
# Saved batch results. Total processed so far: 160
#
# Processing item 161/488 - Title: Would you describe a leopard as yellow? Evaluating...
# Successfully processed item 161 - Category: Ironic
#
# Processing item 162/488 - Title: What's Cookin'? Interpreting Cooking Videos using ...
# Successfully processed item 162 - Category: Epigrammatic
#
# Processing item 163/488 - Title: Mama/Papa, Is this Text for Me?...
# Successfully processed item 163 - Category: Anecdotal
#
# Processing item 164/488 - Title: “Convex Until Proven Guilty”: Dimension-Free Accel...
# Successfully processed item 164 - Category: Ironic
#
# Processing item 165/488 - Title: F1 is Not Enough! Models and Evaluation Towards Us...
# Successfully processed item 165 - Category: Epigrammatic
#
# Processing item 166/488 - Title: "I'd rather just go to bed": Understanding Indirec...
# Successfully processed item 166 - Category: Anecdotal
#
# Processing item 167/488 - Title: No Metrics Are Perfect: Adversarial Reward Learnin...
# Successfully processed item 167 - Category: Ironic
#
# Processing item 168/488 - Title: Think Globally, Act Locally: A Deep Neural Network...
# Successfully processed item 168 - Category: Epigrammatic
#
# Processing item 169/488 - Title: I'm a Belieber: Social Roles via Self-identificati...
# Successfully processed item 169 - Category: Parodic
#
# Processing item 170/488 - Title: CIL: Contrastive Instance Learning Framework for D...
# Successfully processed item 170 - Category: High/highbrow
# Saved batch results. Total processed so far: 170
#
# Processing item 171/488 - Title: DyERNIE: Dynamic Evolution of Riemannian Manifold ...
# Successfully processed item 171 - Category: High/highbrow
#
# Processing item 172/488 - Title: Does my multimodal model learn cross-modal interac...
# Successfully processed item 172 - Category: Ironic
#
# Processing item 173/488 - Title: Dance Revolution: Long-Term Dance Generation with ...
# Successfully processed item 173 - Category: Parodic
#
# Processing item 174/488 - Title: This Text Has the Scent of Starbucks: A Laplacian ...
# Successfully processed item 174 - Category: Ironic
#
# Processing item 175/488 - Title: ERSOM: A Structural Ontology Matching Approach Usi...
# Successfully processed item 175 - Category: High/highbrow
#
# Processing item 176/488 - Title: Beat the Cheater: Computing Game-Theoretic Strateg...
# Successfully processed item 176 - Category: Ironic
#
# Processing item 177/488 - Title: More than Text: Multi-modal Chinese Word Segmentat...
# Successfully processed item 177 - Category: Ironic
#
# Processing item 178/488 - Title: If you've seen some, you've seen them all: Identif...
# Successfully processed item 178 - Category: Ironic
#
# Processing item 179/488 - Title: Don’t Waste Your Bits! Squeeze Activations and Gra...
# Successfully processed item 179 - Category: Epigrammatic
#
# Processing item 180/488 - Title: Examples are not enough, learn to criticize! Criti...
# Successfully processed item 180 - Category: Epigrammatic
# Saved batch results. Total processed so far: 180
#
# Processing item 181/488 - Title: What's the Best Place for an AI Conference, Vancou...
# Successfully processed item 181 - Category: Ironic
#
# Processing item 182/488 - Title: If beam search is the answer, what was the questio...
# Successfully processed item 182 - Category: Ironic
#
# Processing item 183/488 - Title: GRASP: Rich Patterns for Argumentation Mining...
# Successfully processed item 183 - Category: High/highbrow
#
# Processing item 184/488 - Title: DoLFIn: Distributions over Latent Features for Int...
# Successfully processed item 184 - Category: Parodic
#
# Processing item 185/488 - Title: Easy Things First: Installments Improve Referring ...
# Successfully processed item 185 - Category: Ironic
#
# Processing item 186/488 - Title: The State and Fate of Linguistic Diversity and Inc...
# Successfully processed item 186 - Category: Epigrammatic
#
# Processing item 187/488 - Title: Monolingual Marginal Matching for Translation Mode...
# Successfully processed item 187 - Category: High/highbrow
#
# Processing item 188/488 - Title: To Link or Not to Link? A Study on End-to-End Twee...
# Successfully processed item 188 - Category: Parodic
#
# Processing item 189/488 - Title: Are You Looking? Grounding to Multiple Modalities ...
# Successfully processed item 189 - Category: Ironic
#
# Processing item 190/488 - Title: Last Words: That's Nice ... What Can You Do With I...
# Successfully processed item 190 - Category: Ironic
# Saved batch results. Total processed so far: 190
#
# Processing item 191/488 - Title: We Usually Don't Like Going to the Dentist: Using ...
# Successfully processed item 191 - Category: Anecdotal
#
# Processing item 192/488 - Title: ACDC: A Structured Efficient Linear Layer...
# Successfully processed item 192 - Category: Epigrammatic
#
# Processing item 193/488 - Title: Show Me How To Revise: Improving Lexically Constra...
# Successfully processed item 193 - Category: Epigrammatic
#
# Processing item 194/488 - Title: Nutri-bullets: Summarizing Health Studies by Compo...
# Successfully processed item 194 - Category: Parodic
#
# Processing item 195/488 - Title: One Network Fits All? Modular versus Monolithic Ta...
# Successfully processed item 195 - Category: Ironic
#
# Processing item 196/488 - Title: BERTifying the Hidden Markov Model for Multi-Sourc...
# Successfully processed item 196 - Category: Parodic
#
# Processing item 197/488 - Title: Let's Make Your Request More Persuasive: Modeling ...
# Successfully processed item 197 - Category: Epigrammatic
#
# Processing item 198/488 - Title: Let’s Agree to Agree: Neural Networks Share Classi...
# Successfully processed item 198 - Category: Epigrammatic
#
# Processing item 199/488 - Title: Tired of Topic Models? Clusters of Pretrained Word...
# Successfully processed item 199 - Category: Ironic
#
# Processing item 200/488 - Title: Filling the Blanks (hint: plural noun) for Mad Lib...
# Successfully processed item 200 - Category: Epigrammatic
# Saved batch results. Total processed so far: 200
#
# Processing item 201/488 - Title: Beefmoves: Dissemination, Diversity, and Dynamics ...
# Successfully processed item 201 - Category: High/highbrow
#
# Processing item 202/488 - Title: Can a Suit of Armor Conduct Electricity? A New Dat...
# Successfully processed item 202 - Category: Ironic
#
# Processing item 203/488 - Title: Who Likes What? — SplitLBI in Exploring Preferenti...
# Successfully processed item 203 - Category: Epigrammatic
#
# Processing item 204/488 - Title: Saliency is a Possible Red Herring When Diagnosing...
# Successfully processed item 204 - Category: Ironic
#
# Processing item 205/488 - Title: Beto, Bentz, Becas: The Surprising Cross-Lingual E...
# Successfully processed item 205 - Category: Parodic
#
# Processing item 206/488 - Title: Nonparanormal Belief Propagation (NPNBP)...
# Successfully processed item 206 - Category: Parodic
#
# Processing item 207/488 - Title: MedDialog: Large-scale Medical Dialogue Datasets...
# Successfully processed item 207 - Category: High/highbrow
#
# Processing item 208/488 - Title: Action is in the Eye of the Beholder: Eye-gaze Dri...
# Successfully processed item 208 - Category: Epigrammatic
#
# Processing item 209/488 - Title: Don't Give Me the Details, Just the Summary! Topic...
# Successfully processed item 209 - Category: Anecdotal
#
# Processing item 210/488 - Title: The Answer is at your Fingertips: Improving Passag...
# Successfully processed item 210 - Category: Epigrammatic
# Saved batch results. Total processed so far: 210
#
# Processing item 211/488 - Title: Help or Hinder: Bayesian Models of Social Goal Inf...
# Successfully processed item 211 - Category: Epigrammatic
#
# Processing item 212/488 - Title: What-if I ask you to explain: Explaining the effec...
# Successfully processed item 212 - Category: Epigrammatic
#
# Processing item 213/488 - Title: Finding Function in Form: Compositional Character ...
# Successfully processed item 213 - Category: Ironic
#
# Processing item 214/488 - Title: Beat the AI: Investigating Adversarial Human Annot...
# Successfully processed item 214 - Category: Ironic
#
# Processing item 215/488 - Title: BLiMP: The Benchmark of Linguistic Minimal Pairs f...
# Successfully processed item 215 - Category: Epigrammatic
#
# Processing item 216/488 - Title: When Harry Met Harri: Cross-lingual Name Spelling ...
# Successfully processed item 216 - Category: Parodic
#
# Processing item 217/488 - Title: CoADNet: Collaborative Aggregation-and-Distributio...
# Successfully processed item 217 - Category: High/highbrow
#
# Processing item 218/488 - Title: Expressively vulgar: The socio-dynamics of vulgari...
# Successfully processed item 218 - Category: Blue
#
# Processing item 219/488 - Title: iSurvive: An Interpretable, Event-time Prediction ...
# Successfully processed item 219 - Category: Epigrammatic
#
# Processing item 220/488 - Title: Talk'n'Travel: A Conversational System for Air Tra...
# Successfully processed item 220 - Category: Epigrammatic
# Saved batch results. Total processed so far: 220
#
# Processing item 221/488 - Title: The Enemy in Your Own Camp: How Well Can We Detect...
# Successfully processed item 221 - Category: Ironic
#
# Processing item 222/488 - Title: Why Nitpicking Works: Evidence for Occam's Razor i...
# Successfully processed item 222 - Category: Epigrammatic
#
# Processing item 223/488 - Title: Don't Invite BERT to Drink a Bottle: Modeling the ...
# Successfully processed item 223 - Category: Ironic
#
# Processing item 224/488 - Title: 3arif: A Corpus of Modern Standard and Egyptian Ar...
# Successfully processed item 224 - Category: High/highbrow
#
# Processing item 225/488 - Title: What's in the Box? An Analysis of Undesirable Cont...
# Successfully processed item 225 - Category: Ironic
#
# Processing item 226/488 - Title: The Woman Worked as a Babysitter: On Biases in Lan...
# Successfully processed item 226 - Category: Ironic
#
# Processing item 227/488 - Title: May All Your Wishes Come True: A Study of Wishes a...
# Successfully processed item 227 - Category: Epigrammatic
#
# Processing item 228/488 - Title: What's in an Explanation? Characterizing Knowledge...
# Successfully processed item 228 - Category: Epigrammatic
#
# Processing item 229/488 - Title: Deconstruct to Reconstruct a Configurable Evaluati...
# Successfully processed item 229 - Category: Epigrammatic
#
# Processing item 230/488 - Title: "Ask Not What Textual Entailment Can Do for You......
# Successfully processed item 230 - Category: Parodic
# Saved batch results. Total processed so far: 230
#
# Processing item 231/488 - Title: Who's In the Picture...
# Successfully processed item 231 - Category: Epigrammatic
#
# Processing item 232/488 - Title: Be Different to Be Better! A Benchmark to Leverage...
# Successfully processed item 232 - Category: Epigrammatic
#
# Processing item 233/488 - Title: QANom: Question-Answer driven SRL for Nominalizati...
# Successfully processed item 233 - Category: High/highbrow
#
# Processing item 234/488 - Title: Does Size Matter - How Much Data is Required to Tr...
# Successfully processed item 234 - Category: Ironic
#
# Processing item 235/488 - Title: Flight of the PEGASUS? Comparing Transformers on F...
# Successfully processed item 235 - Category: Parodic
#
# Processing item 236/488 - Title: Words or Characters? Fine-grained Gating for Readi...
# Successfully processed item 236 - Category: Epigrammatic
#
# Processing item 237/488 - Title: Winning on the Merits: The Joint Effects of Conten...
# Successfully processed item 237 - Category: High/highbrow
#
# Processing item 238/488 - Title: Writing Polishment with Simile: Task, Dataset and ...
# Successfully processed item 238 - Category: Ironic
#
# Processing item 239/488 - Title: Quantity doesn't buy quality syntax with neural la...
# Successfully processed item 239 - Category: Ironic
#
# Processing item 240/488 - Title: Don't Until the Final Verb Wait: Reinforcement Lea...
# Successfully processed item 240 - Category: Ironic
# Saved batch results. Total processed so far: 240
#
# Processing item 241/488 - Title: Is the Most Accurate AI the Best Teammate? Optimiz...
# Successfully processed item 241 - Category: Ironic
#
# Processing item 242/488 - Title: The red one!: On learning to refer to things based...
# Successfully processed item 242 - Category: Situational
#
# Processing item 243/488 - Title: Man is to Computer Programmer as Woman is to Homem...
# Successfully processed item 243 - Category: Ironic
#
# Processing item 244/488 - Title: Many Languages, One Parser...
# Successfully processed item 244 - Category: Epigrammatic
#
# Processing item 245/488 - Title: This is how we do it: Answer Reranking for Open-do...
# Successfully processed item 245 - Category: Parodic
#
# Processing item 246/488 - Title: STANCY: Stance Classification Based on Consistency...
# Successfully processed item 246 - Category: Epigrammatic
#
# Processing item 247/488 - Title: Are "Undocumented Workers" the Same as "Illegal Al...
# Successfully processed item 247 - Category: Ironic
#
# Processing item 248/488 - Title: Pay Your Trip for Traffic Congestion: Dynamic Pric...
# Successfully processed item 248 - Category: Ironic
#
# Processing item 249/488 - Title: From Bandits to Experts: On the Value of Side-Obse...
# Successfully processed item 249 - Category: Ironic
#
# Processing item 250/488 - Title: Explaining the Stars: Weighted Multiple-Instance L...
# Successfully processed item 250 - Category: Ironic
# Saved batch results. Total processed so far: 250
#
# Processing item 251/488 - Title: Ask what's missing and what's useful: Improving Cl...
# Successfully processed item 251 - Category: Epigrammatic
#
# Processing item 252/488 - Title: PERL: Pivot-based Domain Adaptation for Pre-traine...
# Successfully processed item 252 - Category: Epigrammatic
#
# Processing item 253/488 - Title: "None of the Above": Measure Uncertainty in Dialog...
# Successfully processed item 253 - Category: Epigrammatic
#
# Processing item 254/488 - Title: Sharp Nearby, Fuzzy Far Away: How Neural Language ...
# Successfully processed item 254 - Category: Epigrammatic
#
# Processing item 255/488 - Title: Parsers Know Best: German PP Attachment Revisited...
# Successfully processed item 255 - Category: Ironic
#
# Processing item 256/488 - Title: Pick a Fight or Bite your Tongue: Investigation of...
# Successfully processed item 256 - Category: Epigrammatic
#
# Processing item 257/488 - Title: Sticking the Landing: Simple, Lower-Variance Gradi...
# Successfully processed item 257 - Category: Ironic
#
# Processing item 258/488 - Title: You Talking to Me? A Corpus and Algorithm for Conv...
# Successfully processed item 258 - Category: Ironic
#
# Processing item 259/488 - Title: Taming GANs with Lookahead-Minmax...
# Successfully processed item 259 - Category: Metaphorical titles like 'Taming' suggest a Parodic or perhaps Burlesque style, but considering the anthropomorphizing of GANs as wild creatures to be controlled, the closest match among the categories is Burlesque.
#
# Processing item 260/488 - Title: Simplifying Lexical Simplification: Do We Need Sim...
# Successfully processed item 260 - Category: Ironic
# Saved batch results. Total processed so far: 260
#
# Processing item 261/488 - Title: DeepFuzz: Automatic Generation of Syntax Valid C P...
# Successfully processed item 261 - Category: High/highbrow
#
# Processing item 262/488 - Title: Still not there? Comparing Traditional Sequence-to...
# Successfully processed item 262 - Category: Ironic
#
# Processing item 263/488 - Title: Whodunnit? Crime Drama as a Case for Natural Langu...
# Successfully processed item 263 - Category: Epigrammatic
#
# Processing item 264/488 - Title: Give Me Convenience and Give Her Death: Who Should...
# Successfully processed item 264 - Category: Ironic
#
# Processing item 265/488 - Title: Is Something Better than Nothing? Automatically Pr...
# Successfully processed item 265 - Category: Ironic
#
# Processing item 266/488 - Title: Playing is believing: The role of beliefs in multi...
# Successfully processed item 266 - Category: Epigrammatic
#
# Processing item 267/488 - Title: It's not a Non-Issue: Negation as a Source of Erro...
# Successfully processed item 267 - Category: Ironic
#
# Processing item 268/488 - Title: That's sick dude!: Automatic identification of wor...
# Successfully processed item 268 - Category: Ironic
#
# Processing item 269/488 - Title: Which Side are You on? Identifying Perspectives at...
# Successfully processed item 269 - Category: Ironic
#
# Processing item 270/488 - Title: Vancouver Welcomes You! Minimalist Location Metony...
# Successfully processed item 270 - Category: Ironic
# Saved batch results. Total processed so far: 270
#
# Processing item 271/488 - Title: Overfitting for Fun and Profit: Instance-Adaptive ...
# Successfully processed item 271 - Category: Ironic
#
# Processing item 272/488 - Title: The PARADISE Evaluation Framework: Issues and Find...
# Successfully processed item 272 - Category: High/highbrow
#
# Processing item 273/488 - Title: A Panda? No, It's a Sloth: Slowdown Attacks on Ada...
# Successfully processed item 273 - Category: Ironic
#
# Processing item 274/488 - Title: How emotional are you? Neural Architectures for Em...
# Successfully processed item 274 - Category: Epigrammatic
#
# Processing item 275/488 - Title: How to Ask Better Questions? A Large-Scale Multi-D...
# Successfully processed item 275 - Category: Epigrammatic
#
# Processing item 276/488 - Title: Ruddit: Norms of Offensiveness for English Reddit ...
# Successfully processed item 276 - Category: Parodic
#
# Processing item 277/488 - Title: ENGINE: Energy-Based Inference Networks for Non-Au...
# Successfully processed item 277 - Category: Epigrammatic
#
# Processing item 278/488 - Title: Woulda, Coulda, Shoulda: Counterfactually-Guided P...
# Successfully processed item 278 - Category: Epigrammatic
#
# Processing item 279/488 - Title: The Shattered Gradients Problem: If resnets are th...
# Successfully processed item 279 - Category: Ironic
#
# Processing item 280/488 - Title: Catching the Drift: Probabilistic Content Models, ...
# Successfully processed item 280 - Category: Epigrammatic
# Saved batch results. Total processed so far: 280
#
# Processing item 281/488 - Title: How Many Words Is a Picture Worth? Automatic Capti...
# Successfully processed item 281 - Category: Epigrammatic
#
# Processing item 282/488 - Title: How Many Different "“John Smiths,” and Who Are The...
# Successfully processed item 282 - Category: Anecdotal
#
# Processing item 283/488 - Title: Bucking the Trend: Large-Scale Cost-Focused Active...
# Successfully processed item 283 - Category: Ironic
#
# Processing item 284/488 - Title: Which Tumblr Post Should I Read Next?...
# Successfully processed item 284 - Category: Situational
#
# Processing item 285/488 - Title: BOIL: Towards Representation Change for Few-shot L...
# Successfully processed item 285 - Category: Parodic
#
# Processing item 286/488 - Title: You'll Take the High Road and I'll Take the Low Ro...
# Successfully processed item 286 - Category: Parodic
#
# Processing item 287/488 - Title: The Thieves on Sesame Street are Polyglots - Extra...
# Successfully processed item 287 - Category: Parodic
#
# Processing item 288/488 - Title: BabyWalk: Going Farther in Vision-and-Language Nav...
# Successfully processed item 288 - Category: Ironic
#
# Processing item 289/488 - Title: Still a Pain in the Neck: Evaluating Text Represen...
# Successfully processed item 289 - Category: Ironic
#
# Processing item 290/488 - Title: Are You for Real? Detecting Identity Fraud via Dia...
# Successfully processed item 290 - Category: Ironic
# Saved batch results. Total processed so far: 290
#
# Processing item 291/488 - Title: It's Not You, it's Me: Detecting Flirting and its ...
# Successfully processed item 291 - Category: Ironic
#
# Processing item 292/488 - Title: It's All in the Name: Mitigating Gender Bias with ...
# Successfully processed item 292 - Category: Epigrammatic
#
# Processing item 293/488 - Title: Share or Not? Learning to Schedule Language-Specif...
# Successfully processed item 293 - Category: Ironic
#
# Processing item 294/488 - Title: Fool Me Twice: Entailment from Wikipedia Gamificat...
# Successfully processed item 294 - Category: Ironic
#
# Processing item 295/488 - Title: Less is More: Significance-Based N-gram Selection ...
# Successfully processed item 295 - Category: Ironic
#
# Processing item 296/488 - Title: Hello, Who is Calling?: Can Words Reveal the Socia...
# Successfully processed item 296 - Category: Ironic
#
# Processing item 297/488 - Title: ZEST: Zero-shot Learning from Text Descriptions us...
# Successfully processed item 297 - Category: Epigrammatic
#
# Processing item 298/488 - Title: Partial Or Complete, That's The Question...
# Successfully processed item 298 - Category: Parodic
#
# Processing item 299/488 - Title: Don't let your Discriminator be fooled...
# Successfully processed item 299 - Category: Ironic
#
# Processing item 300/488 - Title: Good Question! Statistical Ranking for Question Ge...
# Successfully processed item 300 - Category: Epigrammatic
# Saved batch results. Total processed so far: 300
#
# Processing item 301/488 - Title: What Makes a Good Counselor? Learning to Distingui...
# Successfully processed item 301 - Category: Epigrammatic
#
# Processing item 302/488 - Title: Just "OneSeC" for Producing Multilingual Sense-Ann...
# Successfully processed item 302 - Category: Epigrammatic
#
# Processing item 303/488 - Title: Don't Let Discourse Confine Your Model: Sequence P...
# Successfully processed item 303 - Category: Ironic
#
# Processing item 304/488 - Title: #SupportTheCause: Identifying Motivations to Parti...
# Successfully processed item 304 - Category: Epigrammatic
#
# Processing item 305/488 - Title: Which Linguist Invented the Lightbulb? Presupposit...
# Successfully processed item 305 - Category: Ironic
#
# Processing item 306/488 - Title: Persuading Voters: It's Easy to Whisper, It's Hard...
# Successfully processed item 306 - Category: Ironic
#
# Processing item 307/488 - Title: Don't take "nswvtnvakgxpm" for an answer -The surp...
# Successfully processed item 307 - Category: Ironic
#
# Processing item 308/488 - Title: oLMpics-On What Language Model Pre-training Captur...
# Successfully processed item 308 - Category: Parodic
#
# Processing item 309/488 - Title: I like fish, especially dolphins: Addressing Contr...
# Successfully processed item 309 - Category: Ironic
#
# Processing item 310/488 - Title: I Can Has Cheezburger? A Nonparanormal Approach to...
# Successfully processed item 310 - Category: Parodic
# Saved batch results. Total processed so far: 310
#
# Processing item 311/488 - Title: Is the Red Square Big? MALeViC: Modeling Adjective...
# Successfully processed item 311 - Category: Ironic
#
# Processing item 312/488 - Title: The Art of Abstention: Selective Prediction and Er...
# Successfully processed item 312 - Category: High/highbrow
#
# Processing item 313/488 - Title: Picking BERT's Brain: Probing for Linguistic Depen...
# Successfully processed item 313 - Category: Ironic
#
# Processing item 314/488 - Title: J-NERD: Joint Named Entity Recognition and Disambi...
# Successfully processed item 314 - Category: Parodic
#
# Processing item 315/488 - Title: Don't Forget the Quantifiable Relationship between...
# Successfully processed item 315 - Category: Epigrammatic
#
# Processing item 316/488 - Title: Optimizing F-measure: A Tale of Two Approaches....
# Successfully processed item 316 - Category: Parodic
#
# Processing item 317/488 - Title: How Can We Know What Language Models Know?...
# Successfully processed item 317 - Category: Ironic
#
# Processing item 318/488 - Title: Learning from My Friends: Few-Shot Personalized Co...
# Successfully processed item 318 - Category: Ironic
#
# Processing item 319/488 - Title: From Zero to Hero: On the Limitations of Zero-Shot...
# Successfully processed item 319 - Category: Ironic
#
# Processing item 320/488 - Title: AprilE: Attention with Pseudo Residual Connection ...
# Successfully processed item 320 - Category: Epigrammatic
# Saved batch results. Total processed so far: 320
#
# Processing item 321/488 - Title: Says Who{\ldots}? Identification of Expert versus ...
# Successfully processed item 321 - Category: Ironic
#
# Processing item 322/488 - Title: Witches' Brew: Industrial Scale Data Poisoning via...
# Successfully processed item 322 - Category: Parodic
#
# Processing item 323/488 - Title: If all you have is a bit of the Bible: Learning PO...
# Successfully processed item 323 - Category: Ironic
#
# Processing item 324/488 - Title: Birds have four legs?! NumerSense: Probing Numeric...
# Successfully processed item 324 - Category: Hyperbolic
#
# Processing item 325/488 - Title: What's with the Attitude? Identifying Sentences wi...
# Successfully processed item 325 - Category: Ironic
#
# Processing item 326/488 - Title: Thumbs Up or Thumbs Down? Semantic Orientation App...
# Successfully processed item 326 - Category: Epigrammatic
#
# Processing item 327/488 - Title: SAFENet: A Secure, Accurate and Fast Neural Networ...
# Successfully processed item 327 - Category: Epigrammatic
#
# Processing item 328/488 - Title: Metrics also Disagree in the Low Scoring Range: Re...
# Successfully processed item 328 - Category: Ironic
#
# Processing item 329/488 - Title: Where Not to Eat? Improving Public Policy by Predi...
# Successfully processed item 329 - Category: Ironic
#
# Processing item 330/488 - Title: Two monolingual parses are better than one (synchr...
# Successfully processed item 330 - Category: Ironic
# Saved batch results. Total processed so far: 330
#
# Processing item 331/488 - Title: Judge the Judges: A Large-Scale Evaluation Study o...
# Successfully processed item 331 - Category: Parodic
#
# Processing item 332/488 - Title: Is Incoherence Surprising? Targeted Evaluation of ...
# Successfully processed item 332 - Category: Ironic
#
# Processing item 333/488 - Title: "You're Mr. Lebowski, I'm the Dude": Inducing Addr...
# Successfully processed item 333 - Category: Anecdotal
#
# ...
# Successfully processed item 396 - Category: Ironic
#
# Processing item 397/488 - Title: Trick Me If You Can: Human-in-the-Loop Generation ...
# Successfully processed item 397 - Category: Ironic
#
# Processing item 398/488 - Title: Have Your Text and Use It Too! End-to-End Neural D...
# Successfully processed item 398 - Category: Ironic
#
# Processing item 399/488 - Title: CO2: Consistent Contrast for Unsupervised Visual R...
# Successfully processed item 399 - Category: Epigrammatic
#
# Processing item 400/488 - Title: Sentence-Level Fluency Evaluation: References Help...
# Successfully processed item 400 - Category: Ironic
# Saved batch results. Total processed so far: 400
#
# Processing item 401/488 - Title: From Language to Language-ish: How Brain-Like is a...
# Successfully processed item 401 - Category: Ironic
#
# Processing item 402/488 - Title: BERT is to NLP what AlexNet is to CV: Can Pre-Trai...
# Successfully processed item 402 - Category: Ironic
#
# Processing item 403/488 - Title: To Attend or not to Attend: A Case Study on Syntac...
# Successfully processed item 403 - Category: Ironic
#
# Processing item 404/488 - Title: This Email Could Save Your Life: Introducing the T...
# Successfully processed item 404 - Category: Hyperbolic
#
# Processing item 405/488 - Title: Real or Not Real, that is the Question...
# Successfully processed item 405 - Category: Parodic
#
# Processing item 406/488 - Title: BERTAC: Enhancing Transformer-based Language Model...
# Successfully processed item 406 - Category: High/highbrow
#
# Processing item 407/488 - Title: Very quaffable and great fun: Applying NLP to wine...
# Successfully processed item 407 - Category: Ironic
#
# Processing item 408/488 - Title: CAMOU: Learning Physical Vehicle Camouflages to Ad...
# Successfully processed item 408 - Category: Ironic
#
# Processing item 409/488 - Title: RIDE: Rewarding Impact-Driven Exploration for Proc...
# Successfully processed item 409 - Category: Epigrammatic
#
# Processing item 410/488 - Title: Everybody loves a rich cousin: An empirical study ...
# Successfully processed item 410 - Category: Metaphoric/Ironic
# Saved batch results. Total processed so far: 410
#
# Processing item 411/488 - Title: One Vector is Not Enough: Entity-Augmented Distrib...
# Successfully processed item 411 - Category: Epigrammatic
#
# Processing item 412/488 - Title: Are Adversarial Examples Created Equal? A Learnabl...
# Successfully processed item 412 - Category: Ironic
#
# Processing item 413/488 - Title: #YouToo? Detection of Personal Recollections of Se...
# Successfully processed item 413 - Category: Ironic
#
# Processing item 414/488 - Title: Colors in Context: A Pragmatic Neural Model for Gr...
# Successfully processed item 414 - Category: High/highbrow
#
# Processing item 415/488 - Title: Will I Sound Like Me? Improving Persona Consistenc...
# Successfully processed item 415 - Category: Ironic
#
# Processing item 416/488 - Title: How Much is 131 Million Dollars? Putting Numbers i...
# Successfully processed item 416 - Category: Ironic
#
# Processing item 417/488 - Title: Frowning Frodo, Wincing Leia, and a Seriously Grea...
# Successfully processed item 417 - Category: Anecdotal
#
# Processing item 418/488 - Title: KERMIT: Complementing Transformer Architectures wi...
# Successfully processed item 418 - Category: Parodic
#
# Processing item 419/488 - Title: Don't Settle for Average, Go for the Max: Fuzzy Se...
# Successfully processed item 419 - Category: Epigrammatic
#
# Processing item 420/488 - Title: BANANAS: Bayesian Optimization with Neural Archite...
# Successfully processed item 420 - Category: Epigrammatic
# Saved batch results. Total processed so far: 420
#
# Processing item 421/488 - Title: OPAL: Offline Primitive Discovery for Accelerating...
# Successfully processed item 421 - Category: Acronym-based titles such as 'OPAL' tend to have a subtle lighthearted tone, but within these categories, the closest is 'High/highbrow' due to its cleverness and sophistication
#
# Processing item 422/488 - Title: The Good, the Bad, and the Unknown: Morphosyllabic...
# Successfully processed item 422 - Category: Parodic
#
# Processing item 423/488 - Title: "How Bullying is this Message?": A Psychometric Th...
# Successfully processed item 423 - Category: Ironic
#
# Processing item 424/488 - Title: Will-They-Won't-They: A Very Large Dataset for Sta...
# Successfully processed item 424 - Category: Epigrammatic
#
# Processing item 425/488 - Title: Go Simple and Pre-Train on Domain-Specific Corpora...
# Successfully processed item 425 - Category: Epigrammatic
#
# Processing item 426/488 - Title: Novel Is Not Always Better: On the Relation betwee...
# Successfully processed item 426 - Category: Ironic
#
# Processing item 427/488 - Title: CPR: Classifier-Projection Regularization for Cont...
# Successfully processed item 427 - Category: Epigrammatic
#
# Processing item 428/488 - Title: XHate-999: Analyzing and Detecting Abusive Languag...
# Successfully processed item 428 - Category: High/highbrow
#
# Processing item 429/488 - Title: Towards Ghost-Free Shadow Removal via Dual Hierarc...
# Successfully processed item 429 - Category: Dark/Gallows/Morbid
#
# Processing item 430/488 - Title: No Answer is Better Than Wrong Answer: A Reflectio...
# Successfully processed item 430 - Category: Epigrammatic
# Saved batch results. Total processed so far: 430
#
# Processing item 431/488 - Title: From Zero to Hero: Human-In-The-Loop Entity Linkin...
# Successfully processed item 431 - Category: Hyperbolic
#
# Processing item 432/488 - Title: Polyjuice: Generating Counterfactuals for Explaini...
# Successfully processed item 432 - Category: Parodic
#
# Processing item 433/488 - Title: Make Up Your Mind! Adversarial Generation of Incon...
# Successfully processed item 433 - Category: Epigrammatic
#
# Processing item 434/488 - Title: Beyond the Chinese Restaurant and Pitman-Yor proce...
# Successfully processed item 434 - Category: Parodic
#
# Processing item 435/488 - Title: Kickback Cuts Backprop's Red-Tape: Biologically Pl...
# Successfully processed item 435 - Category: Ironic
#
# Processing item 436/488 - Title: TextSETTR: Few-Shot Text Style Extraction and Tuna...
# Successfully processed item 436 - Category: High/highbrow
#
# Processing item 437/488 - Title: DExperts: Decoding-Time Controlled Text Generation...
# Successfully processed item 437 - Category: High/highbrow
#
# Processing item 438/488 - Title: All Fingers are not Equal: Intensity of References...
# Successfully processed item 438 - Category: Ironic
#
# Processing item 439/488 - Title: Who Also Likes It? Generating the Most Persuasive ...
# Successfully processed item 439 - Category: Epigrammatic
#
# Processing item 440/488 - Title: SentiLARE: Sentiment-Aware Language Representation...
# Successfully processed item 440 - Category: High/highbrow
# Saved batch results. Total processed so far: 440
#
# Processing item 441/488 - Title: Where to Submit? Helping Researchers to Choose the...
# Successfully processed item 441 - Category: Situational
#
# Processing item 442/488 - Title: Sarcastic or Not: Word Embeddings to Predict the L...
# Successfully processed item 442 - Category: Ironic
#
# Processing item 443/488 - Title: R4C: A Benchmark for Evaluating RC Systems to Get ...
# Successfully processed item 443 - Category: Epigrammatic
#
# Processing item 444/488 - Title: Is a 204 cm Man Tall or Small ? Acquisition of Num...
# Successfully processed item 444 - Category: Situational
#
# Processing item 445/488 - Title: COSY: COunterfactual SYntax for Cross-Lingual Unde...
# Successfully processed item 445 - Category: Epigrammatic
#
# Processing item 446/488 - Title: WER we are and WER we think we are...
# Successfully processed item 446 - Category: Ironic
#
# Processing item 447/488 - Title: OntoGUM: Evaluating Contextualized SOTA Coreferenc...
# Successfully processed item 447 - Category: High/highbrow
#
# Processing item 448/488 - Title: PARMA: A Predicate Argument Aligner...
# Successfully processed item 448 - Category: High/highbrow
#
# Processing item 449/488 - Title: From Bandits to Experts: A Tale of Domination and ...
# Successfully processed item 449 - Category: Parodic
#
# Processing item 450/488 - Title: CAN: Constrained Attention Networks for Multi-Aspe...
# Successfully processed item 450 - Category: Epigrammatic
# Saved batch results. Total processed so far: 450
#
# Processing item 451/488 - Title: CancerEmo: A Dataset for Fine-Grained Emotion Dete...
# Successfully processed item 451 - Category: Epigrammatic
#
# Processing item 452/488 - Title: Speaking, Seeing, Understanding: Correlating seman...
# Successfully processed item 452 - Category: Epigrammatic
#
# Processing item 453/488 - Title: Look Who is Talking: Soundbite Speaker Name Recogn...
# Successfully processed item 453 - Category: Ironic
#
# Processing item 454/488 - Title: Reading Tea Leaves: How Humans Interpret Topic Mod...
# Successfully processed item 454 - Category: Ironic
#
# Processing item 455/488 - Title: Entity Extraction is a Boring Solved Problem-Or is...
# Successfully processed item 455 - Category: Ironic
#
# Processing item 456/488 - Title: Less is More: Nyström Computational Regularization...
# Successfully processed item 456 - Category: Ironic
#
# Processing item 457/488 - Title: Does Syntax Need to Grow on Trees? Sources of Hier...
# Successfully processed item 457 - Category: Ironic
#
# Processing item 458/488 - Title: Wetin dey with these comments? Modeling Sociolingu...
# Successfully processed item 458 - Category: Anecdotal
#
# Processing item 459/488 - Title: He said "who's gonna take care of your children wh...
# Successfully processed item 459 - Category: Ironic
#
# Processing item 460/488 - Title: Reading Like HER: Human Reading Inspired Extractiv...
# Successfully processed item 460 - Category: Ironic
# Saved batch results. Total processed so far: 460
#
# Processing item 461/488 - Title: The Uncommon Denominator: A Proposal for Consisten...
# Successfully processed item 461 - Category: Ironic
#
# Processing item 462/488 - Title: Black Holes and White Rabbits: Metaphor Identifica...
# Successfully processed item 462 - Category: High/highbrow
#
# Processing item 463/488 - Title: Online Pandora’s Boxes and Bandits...
# Successfully processed item 463 - Category: Parodic
#
# Processing item 464/488 - Title: TED: A Pretrained Unsupervised Summarization Model...
# Successfully processed item 464 - Category: Epigrammatic
#
# Processing item 465/488 - Title: STARC: Structured Annotations for Reading Comprehe...
# Successfully processed item 465 - Category: High/highbrow
#
# Processing item 466/488 - Title: Right for Better Reasons: Training Differentiable ...
# Successfully processed item 466 - Category: Epigrammatic
#
# Processing item 467/488 - Title: SCRUPLES: A Corpus of Community Ethical Judgments ...
# Successfully processed item 467 - Category: Anecdotal
#
# Processing item 468/488 - Title: Most "babies" are "little" and most "problems" are...
# Successfully processed item 468 - Category: Ironic
#
# Processing item 469/488 - Title: Biographies, Bollywood, Boom-boxes and Blenders: D...
# Successfully processed item 469 - Category: Epigrammatic
#
# Processing item 470/488 - Title: COSMIC: COmmonSense knowledge for eMotion Identifi...
# Successfully processed item 470 - Category: Epigrammatic
# Saved batch results. Total processed so far: 470
#
# Processing item 471/488 - Title: PowerTransformer: Unsupervised Controllable Revisi...
# Successfully processed item 471 - Category: High/highbrow
#
# Processing item 472/488 - Title: LexFit: Lexical Fine-Tuning of Pretrained Language...
# Successfully processed item 472 - Category: High/highbrow
#
# Processing item 473/488 - Title: Did That Lost Ballot Box Cost Me a Seat? Computing...
# Successfully processed item 473 - Category: Anecdotal
#
# Processing item 474/488 - Title: You Only Need Attention to Traverse Trees...
# Successfully processed item 474 - Category: Ironic
#
# Processing item 475/488 - Title: Point to the Expression: Solving Algebraic Word Pr...
# Successfully processed item 475 - Category: Epigrammatic
#
# Processing item 476/488 - Title: Jelly Bean World: A Testbed for Never-Ending Learn...
# Successfully processed item 476 - Category: Droll
#
# Processing item 477/488 - Title: All you need is a good init...
# Successfully processed item 477 - Category: Parodic
#
# Processing item 478/488 - Title: BRAINSUP: Brainstorming Support for Creative Sente...
# Successfully processed item 478 - Category: Epigrammatic
#
# Processing item 479/488 - Title: PhoneMD: Learning to Diagnose Parkinson’s Disease ...
# Successfully processed item 479 - Category: Epigrammatic
#
# Processing item 480/488 - Title: PAWS: Paraphrase Adversaries from Word Scrambling...
# Successfully processed item 480 - Category: Parodic
# Saved batch results. Total processed so far: 480
#
# Processing item 481/488 - Title: Yggdrasil: An Optimized System for Training Deep D...
# Successfully processed item 481 - Category: High/highbrow
#
# Processing item 482/488 - Title: DiffTaichi: Differentiable Programming for Physica...
# Successfully processed item 482 - Category: High/highbrow
#
# Processing item 483/488 - Title: Causal meets Submodular: Subset Selection with Dir...
# Successfully processed item 483 - Category: Ironic
#
# Processing item 484/488 - Title: DeeBERT: Dynamic Early Exiting for Accelerating BE...
# Successfully processed item 484 - Category: High/highbrow
#
# Processing item 485/488 - Title: SwitchOut: an Efficient Data Augmentation Algorith...
# Successfully processed item 485 - Category: Epigrammatic
#
# Processing item 486/488 - Title: POPQORN: Quantifying Robustness of Recurrent Neura...
# Successfully processed item 486 - Category: Epigrammatic
#
# Processing item 487/488 - Title: "Who said it, and Why?" Provenance for Natural Lan...
# Successfully processed item 487 - Category: Epigrammatic
#
# Processing item 488/488 - Title: Multi-Domain Goal-Oriented Dialogues (MultiDoGO): ...
# Successfully processed item 488 - Category: High/highbrow
# Saved final batch. Total processed: 488
#
# Processing complete. Total results: 488
#
# Humor Category Distribution:
#   Ironic: 187 (38.3%)
#   Epigrammatic: 150 (30.7%)
#   High/highbrow: 55 (11.3%)
#   Parodic: 52 (10.7%)
#   Anecdotal: 14 (2.9%)
#   Hyperbolic: 10 (2.0%)
#   Situational: 7 (1.4%)
#   Blue: 2 (0.4%)
#   Dark/Gallows/Morbid: 2 (0.4%)
#   Droll: 2 (0.4%)
#   Metaphoric/Ironic: 1 (0.2%)
#   Metaphorical titles like 'Taming' suggest a Parodic or perhaps Burlesque style, but considering the anthropomorphizing of GANs as wild creatures to be controlled, the closest match among the categories is Burlesque.: 1 (0.2%)
#   Personification with a light, ironic tone—primarily Ironic: 1 (0.2%)
#   Metaphorical and personifying titles like 'Finding the Storyteller' generally fall under the Ironic category, as they play on expectations by anthropomorphizing or using incongruity with the literal task description. So, the humor category is 'Ironic'.: 1 (0.2%)
#   Burlesque: 1 (0.2%)
#   Descriptive titles like this are straightforward and not humorous. The original title contains an informal, playful tone with the term 'PhotoChat', which personifies the dataset, mildly bordering on 'Droll' (6). However, since the focus is classification, the best match is 'Droll'.: 1 (0.2%)
#   Acronym-based titles such as 'OPAL' tend to have a subtle lighthearted tone, but within these categories, the closest is 'High/highbrow' due to its cleverness and sophistication: 1 (0.2%)
#
# Sample of results:
#                                       original_title  \
# 0  "You are grounded!": Latent Name Artifacts in ...
# 1  Nouns are Vectors, Adjectives are Matrices: Re...
# 2  Here's My Point: Joint Pointer Architecture fo...
# 3  Is it Time to Swish? Comparing Deep Learning A...
# 4  To Boldly Query What No One Has Annotated Befo...
#
#                                        created_title humor_category
# 0  An Analysis of Bias and Name-Related Artifacts...         Ironic
# 1  A Data-Driven Method for Representing Adjectiv...         Ironic
# 2  A Joint Neural Network Model for Link Extracti...   Epigrammatic
# 3  A Comprehensive Benchmarking of 21 Activation ...   Epigrammatic
# 4  A Survey of Corpus Query Systems and Their Dev...        Parodic

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Define the correct humor categories from the given list
VALID_CATEGORIES = [
    "Anecdotal", "Blue", "Burlesque", "Dark/Gallows/Morbid", "Deadpan/Dry", 
    "Droll", "Epigrammatic", "Farcical", "High/highbrow", "Hyperbolic",
    "Ironic", "Juvenile/sophomoric", "Mordant", "Parodic", "Satirical",
    "Screwball", "Self-deprecating", "Situational", "Slapstick", "Stand-up"
]

# Load the results data
results_file = 'humor_classification_results.csv'
df = pd.read_csv(results_file)

print(f"Total entries in dataset: {len(df)}")

# Extract the humor category column
humor_categories = df['humor_category']

# Count the occurrences of each category
category_counts = humor_categories.value_counts().reset_index()
category_counts.columns = ['Category', 'Count']

# Identify categories not in the valid list
valid_mask = category_counts['Category'].isin(VALID_CATEGORIES)
valid_categories = category_counts[valid_mask]
invalid_categories = category_counts[~valid_mask]

# Print statistics
print("\n--- Category Statistics ---")
print(f"Number of unique categories: {len(category_counts)}")
print(f"Valid categories found: {len(valid_categories)}")
print(f"Invalid categories found: {len(invalid_categories)}")

# Sort valid categories by count (descending)
valid_categories = valid_categories.sort_values('Count', ascending=False)

# Set up the visualization
plt.figure(figsize=(14, 8))
sns.set_style("whitegrid")

# Plot valid categories
ax = sns.barplot(x='Category', y='Count', data=valid_categories, palette='viridis')

# Customize the plot
plt.title('Distribution of Humor Categories', fontsize=18)
plt.xlabel('Humor Category', fontsize=14)
plt.ylabel('Number of Titles', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout()

# Add count labels on top of bars
for i, p in enumerate(ax.patches):
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2., height + 0.5,
            f'{int(height)}',
            ha="center", fontsize=10)

# Save the plot

# Display the plot
plt.show()

# If invalid categories exist, show them too
if len(invalid_categories) > 0:
    print("\n--- Invalid Categories Found ---")
    print(invalid_categories)
    
    # Plot invalid categories
    plt.figure(figsize=(12, 6))
    sns.barplot(x='Category', y='Count', data=invalid_categories, palette='Reds')
    plt.title('Invalid Humor Categories (Not in Predefined List)', fontsize=18)
    plt.xlabel('Category', fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Generate a pie chart for overall distribution
plt.figure(figsize=(12, 12))
colors = sns.color_palette('viridis', len(valid_categories))

# Only include categories with significant counts for better readability
threshold = 3  # Minimum count to be shown separately in pie chart
significant_cats = valid_categories[valid_categories['Count'] >= threshold]
other_count = valid_categories[valid_categories['Count'] < threshold]['Count'].sum()

# Add "Other" category if needed
if other_count > 0:
    significant_cats = pd.concat([
        significant_cats, 
        pd.DataFrame({'Category': ['Other (less frequent)'], 'Count': [other_count]})
    ])

# Create pie chart
plt.pie(
    significant_cats['Count'], 
    labels=significant_cats['Category'], 
    autopct='%1.1f%%',
    colors=sns.color_palette('viridis', len(significant_cats)),
    startangle=90,
    shadow=False,
    textprops={'fontsize': 12}
)
plt.axis('equal')
plt.title('Proportion of Humor Categories', fontsize=18)
plt.tight_layout()
plt.show()

# Find missing categories (from the valid list but not present in data)
present_categories = set(valid_categories['Category'])
missing_categories = [cat for cat in VALID_CATEGORIES if cat not in present_categories]

if missing_categories:
    print("\n--- Categories Not Present in the Dataset ---")
    for cat in missing_categories:
        print(f"- {cat}")

# Show top 5 examples from the most common categories
print("\n--- Examples from Top Categories ---")
for category in valid_categories['Category'].head(3):  # Top 3 categories
    print(f"\nCategory: {category}")
    examples = df[df['humor_category'] == category][['original_title', 'created_title']].head(2)
    for i, (original, created) in enumerate(zip(examples['original_title'], examples['created_title'])):
        print(f"Example {i+1}:")
        print(f"  Original: {original}")
        print(f"  Created:  {created}")
# Out:
# Total entries in dataset: 488
#
# --- Category Statistics ---
# Number of unique categories: 13
# Valid categories found: 11
# Invalid categories found: 2
# --- Invalid Categories Found ---
#              Category  Count
# 11         Burlesque.      1
# 12  Metaphoric/Ironic      1
# --- Categories Not Present in the Dataset ---
# - Deadpan/Dry
# - Farcical
# - Juvenile/sophomoric
# - Mordant
# - Satirical
# - Screwball
# - Self-deprecating
# - Slapstick
# - Stand-up
#
# --- Examples from Top Categories ---
#
# Category: Ironic
# Example 1:
#   Original: "You are grounded!": Latent Name Artifacts in Pre-trained Language Models
#   Created:  An Analysis of Bias and Name-Related Artifacts in Pre-Trained Language Models and Implications for Downstream Tasks
# Example 2:
#   Original: Nouns are Vectors, Adjectives are Matrices: Representing Adjective-Noun Constructions in Semantic Space
#   Created:  A Data-Driven Method for Representing Adjective-Noun Compositions in Distributional Semantic Models
#
# Category: Epigrammatic
# Example 1:
#   Original: Here's My Point: Joint Pointer Architecture for Argument Mining
#   Created:  A Joint Neural Network Model for Link Extraction and Component Classification in Argument Mining Using Pointer Networks
# Example 2:
#   Original: Is it Time to Swish? Comparing Deep Learning Activation Functions Across NLP tasks
#   Created:  A Comprehensive Benchmarking of 21 Activation Functions on Multiple NLP Tasks and Their Effects in LSTM Architectures
#
# Category: High/highbrow
# Example 1:
#   Original: MangaGAN: Unpaired Photo-to-Manga Translation Based on The Methodology of Manga Drawing
#   Created:  A Generative Adversarial Network Approach for Translating Unpaired Photographic Images into Manga Style Using Geometric Feature Generation and Domain Similarity Preservation
# Example 2:
#   Original: OoMMix: Out-of-manifold Regularization in Contextual Embedding Space for Text Classification
#   Created:  A Method for Synthesizing and Regularizing Out-of-Manifold Embeddings to Improve Fine-Tuning of Pre-Trained Language Models in Text Classification Tasks
